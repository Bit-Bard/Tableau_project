# %% [markdown]
# **We have 5 datasets based on our need we will clean them one by one**

# %% [markdown]
# **Dataset 1 = Netflix movievs and TV shows**

# %%
import numpy as np
import pandas as pd

# %%
data1=pd.read_csv("Netflix Movies and TV Shows Metadata/netflix_titles.csv")
data1.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data1.shape
# Out:
# (8807, 12)

# %%
data1.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
data1['rating'].isnull().sum()
# Out:
# 4

# %%
null = data1[data1['rating'].isnull()]
null
# Out:
#      show_id     type                                              title  \
# 5989   s5990    Movie  13TH: A Conversation with Oprah Winfrey & Ava ...
# 6827   s6828  TV Show                  Gargantia on the Verdurous Planet
# 7312   s7313  TV Show                                       Little Lunch
# 7537   s7538    Movie                               My Honor Was Loyalty
#
#              director                                               cast  \
# 5989              NaN                        Oprah Winfrey, Ava DuVernay
# 6827              NaN  Kaito Ishikawa, Hisako Kanemoto, Ai Kayano, Ka...
# 7312              NaN  Flynn Curry, Olivia Deeble, Madison Lu, Oisín ...
# 7537  Alessandro Pepe  Leone Frisa, Paolo Vaccarino, Francesco Miglio...
#
#         country        date_added  release_year rating  duration  \
# 5989        NaN  January 26, 2017          2017    NaN    37 min
# 6827      Japan  December 1, 2016          2013    NaN  1 Season
# ...

# %%
data1['type'].nunique()
# Out:
# 2

# %%
data1['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
data1['listed_in'].unique()
# Out:
# array(['Documentaries', 'International TV Shows, TV Dramas, TV Mysteries',
#        'Crime TV Shows, International TV Shows, TV Action & Adventure',
#        'Docuseries, Reality TV',
#        'International TV Shows, Romantic TV Shows, TV Comedies',
#        'TV Dramas, TV Horror, TV Mysteries', 'Children & Family Movies',
#        'Dramas, Independent Movies, International Movies',
#        'British TV Shows, Reality TV', 'Comedies, Dramas',
#        'Crime TV Shows, Docuseries, International TV Shows',
#        'Dramas, International Movies',
#        'Children & Family Movies, Comedies',
#        'British TV Shows, Crime TV Shows, Docuseries',
#        'TV Comedies, TV Dramas', 'Documentaries, International Movies',
#        'Crime TV Shows, Spanish-Language TV Shows, TV Dramas',
#        'Thrillers',
#        'International TV Shows, Spanish-Language TV Shows, TV Action & Adventure',
#        'International TV Shows, TV Action & Adventure, TV Dramas',
# ...

# %%
data1 = data1.dropna(subset=['rating'])
data1=data1.dropna(subset=['duration'])
data1=data1.drop(['date_added'], axis=1)
# data1=data1.dropna(['Nr'])
data1.shape
# Out:
# (8800, 11)

# %%
data1['director']=data1['director'].fillna('unknown')
data1['cast']=data1['cast'].fillna('unknown')
data1['country']=data1['country'].fillna('unknown')

# %%
data1.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
data1.to_csv("Netflix Movies and TV Shows[Cleaned].csv",index=False)

# %% [markdown]
# **Dataset 2 = Netflix Plans and prices**

# %%
data2=pd.read_csv("Netflix Plans & Prices/Netflix Prices.csv")
data2.head()
#| Country | Code | Currency (optional) | Mobile_USD | Basic_USD | Standard_USD | Premium_USD |
# Out:
#          Country Code           Currency Mobile     Basic  Standard   Premium  \
# 0       Viet Nam   VN    Vietnamese Dong  70000  180000.0  220000.0  260000.0
# 1      Indonesia   ID  Indonesian Rupiah  54000  120000.0  153000.0  186000.0
# 2       Colombia   CO     Colombian Peso      -   16900.0   26900.0   38900.0
# 3  Korea�(South)   KR         Korean Won      -    9500.0   13500.0   17000.0
# 4          Chile   CL       Chilean Peso      -    5940.0    8320.0   10700.0
#
#    Conversion Mobile_USD  Basic_USD  Standard_USD  Premium_USD
# 0    0.000043       3.01      7.740         9.460       11.180
# 1    0.000070       3.78      8.400        10.710       13.020
# 2    0.000250          -      4.225         6.725        9.725
# 3    0.000845          -      8.028        11.408       14.365
# 4    0.001175          -      6.980         9.776       12.572

# %%
data2.shape
# Out:
# (243, 12)

# %%
data2.columns
# Out:
# Index(['Country', 'Code', 'Currency', 'Mobile', 'Basic', 'Standard', 'Premium',
#        'Conversion', 'Mobile_USD', 'Basic_USD', 'Standard_USD', 'Premium_USD'],
#       dtype='object')

# %%
data2.isnull().sum()
# Out:
# Country         0
# Code            1
# Currency        0
# Mobile          0
# Basic           0
# Standard        0
# Premium         0
# Conversion      0
# Mobile_USD      0
# Basic_USD       0
# Standard_USD    0
# Premium_USD     0
# dtype: int64

# %%
col_to_drop = ['Currency', 'Mobile', 'Basic', 'Standard', 'Premium', 'Conversion']
data2 = data2.drop(col_to_drop, axis=1)

# %%
data2.isnull().sum()
# Out:
# Country         0
# Code            1
# Mobile_USD      0
# Basic_USD       0
# Standard_USD    0
# Premium_USD     0
# dtype: int64

# %%
data2=data2.dropna(subset='Code')

# %%
data2['Mobile_USD'].unique()
# Out:
# array(['3.01', '3.78', '-', '2.88', '1.403', '2.64', '1.956', '2.98',
#        '2.958', '3.065', '4.039', '3.99', '4.59', '4.49'], dtype=object)

# %%
data2['Mobile_USD'] = data2['Mobile_USD'].replace('-', np.nan).astype(float)

# %%
data2['Mobile_USD']=data2['Mobile_USD'].fillna('Not Available')

# %%
data2.to_csv("Netflix Plans and Prices[Cleaned].csv", index=False)

# %% [markdown]
# **DataSet 3 = Netflix subscriber And Revenue overtime**

# %%
data3=pd.read_csv("Netflix Subscribers & Revenue Over Time/netflix_revenue_updated.csv")
data3.head()
# Out:
#          Date  Global Revenue  UCAN Streaming Revenue  EMEA Streaming Revenue  \
# 0  31-03-2019      4520992000              2256851000              1233379000
# 1  30-06-2019      4923116000              2501199000              1319087000
# 2  30-09-2019      5244905000              2621250000              1428040000
# 3  31-12-2019      5467434000              2671908000              1562561000
# 4  31-03-2020      5767691000              2702776000              1723474000
#
#    LATM Streaming Revenue  APAC Streaming Revenue  UCAN Members  \
# 0               630472000               319602000      66633000
# 1               677136000               349494000      66501000
# 2               741434000               382304000      67114000
# 3               746392000               418121000      67662000
# 4               793453000               483660000      69969000
#
#    EMEA  Members  LATM Members  APAC Members  UCAN ARPU  EMEA ARPU  \
# ...

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Date                            21 non-null     object
#  1   Global Revenue                  21 non-null     int64
#  2   UCAN Streaming Revenue          21 non-null     int64
#  3   EMEA Streaming Revenue          21 non-null     int64
#  4   LATM Streaming Revenue          21 non-null     int64
#  5   APAC Streaming Revenue          21 non-null     int64
#  6   UCAN Members                    21 non-null     int64
#  7   EMEA  Members                   21 non-null     int64
#  8   LATM Members                    21 non-null     int64
#  9   APAC Members                    21 non-null     int64
#  10  UCAN ARPU                       21 non-null     float64
#  11  EMEA ARPU                       21 non-null     float64
# ...

# %%
data3.shape
# Out:
# (21, 15)

# %%
data3.isnull().sum()
# Out:
# Date                              0
# Global Revenue                    0
# UCAN Streaming Revenue            0
# EMEA Streaming Revenue            0
# LATM Streaming Revenue            0
# APAC Streaming Revenue            0
# UCAN Members                      0
# EMEA  Members                     0
# LATM Members                      0
# APAC Members                      0
# UCAN ARPU                         0
# EMEA ARPU                         0
# LATM  ARPU                        0
# APAC  ARPU                        0
# Netflix Streaming Memberships     0
# dtype: int64

# %%
data3['Date']=pd.to_datetime(data3['Date'],format='%d-%m-%Y')

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Date                            21 non-null     datetime64[ns]
#  1   Global Revenue                  21 non-null     int64
#  2   UCAN Streaming Revenue          21 non-null     int64
#  3   EMEA Streaming Revenue          21 non-null     int64
#  4   LATM Streaming Revenue          21 non-null     int64
#  5   APAC Streaming Revenue          21 non-null     int64
#  6   UCAN Members                    21 non-null     int64
#  7   EMEA  Members                   21 non-null     int64
#  8   LATM Members                    21 non-null     int64
#  9   APAC Members                    21 non-null     int64
#  10  UCAN ARPU                       21 non-null     float64
#  11  EMEA ARPU                       21 non-null     float64
# ...

# %%
data3.columns
# Out:
# Index(['Date', 'Global Revenue', 'UCAN Streaming Revenue',
#        'EMEA Streaming Revenue', 'LATM Streaming Revenue',
#        'APAC Streaming Revenue', 'UCAN Members', 'EMEA  Members',
#        'LATM Members', 'APAC Members', 'UCAN ARPU', 'EMEA ARPU', 'LATM  ARPU',
#        'APAC  ARPU', 'Netflix Streaming Memberships '],
#       dtype='object')

# %%
rename_columns = {
    'UCAN Streaming Revenue': 'Revenue_US_Canada',
    'EMEA Streaming Revenue': 'Revenue_Europe_MiddleEast_Africa',
    'LATM Streaming Revenue': 'Revenue_LatinAmerica',
    'APAC Streaming Revenue': 'Revenue_AsiaPacific',
    'UCAN Members': 'Subscribers_US_Canada',
    'EMEA  Members': 'Subscribers_Europe_MiddleEast_Africa',
    'LATM Members': 'Subscribers_LatinAmerica',
    'APAC Members': 'Subscribers_AsiaPacific',
    'UCAN ARPU': 'ARPU_US_Canada',
    'EMEA ARPU': 'ARPU_Europe_MiddleEast_Africa',
    'LATM  ARPU': 'ARPU_LatinAmerica',
    'APAC  ARPU': 'ARPU_AsiaPacific',
}

# %%
data3.rename(columns=rename_columns, inplace=True)
data3.head()
# Out:
#         Date  Global Revenue  Revenue_US_Canada  \
# 0 2019-03-31      4520992000         2256851000
# 1 2019-06-30      4923116000         2501199000
# 2 2019-09-30      5244905000         2621250000
# 3 2019-12-31      5467434000         2671908000
# 4 2020-03-31      5767691000         2702776000
#
#    Revenue_Europe_MiddleEast_Africa  Revenue_LatinAmerica  \
# 0                        1233379000             630472000
# 1                        1319087000             677136000
# 2                        1428040000             741434000
# 3                        1562561000             746392000
# 4                        1723474000             793453000
#
#    Revenue_AsiaPacific  Subscribers_US_Canada  \
# 0            319602000               66633000
# 1            349494000               66501000
# 2            382304000               67114000
# 3            418121000               67662000
# 4            483660000               69969000
#
# ...

# %%
data3.to_csv("Netflix Sub and Revnue overtime [Cleaned].csv", index=False)

# %% [markdown]
# **Dataset 4 = Netflix veiwing activity and watchlog**

# %% [markdown]
# **there are 5 sub csv**

# %%
data4_1=pd.read_csv("Netflix Viewing Activity  Watch Log/All_Clickstream.csv")
data4_2=pd.read_csv("Netflix Viewing Activity  Watch Log/All_Devices.csv")
data4_3=pd.read_csv("Netflix Viewing Activity  Watch Log/All_Profiles.csv")
data4_4=pd.read_csv("Netflix Viewing Activity  Watch Log/All_SearchHistory.csv")
data4_5=pd.read_csv("Netflix Viewing Activity  Watch Log/All_ViewingActivity.csv")

# %%
data4_1.head()
# Out:
#   Profile Name    Source Navigation Level Referrer Url Webpage Url  \
# 0       User 4  Source 0     signupPrompt          NaN         NaN
# 1       User 4  Source 0     browseTitles          NaN         NaN
# 2       User 4  Source 1     movieDetails          NaN         NaN
# 3       User 4  Source 1     browseTitles          NaN         NaN
# 4       User 4  Source 1     movieDetails          NaN         NaN
#
#           Click Utc Ts
# 0  2022-10-08 14:04:47
# 1  2022-10-08 14:04:46
# 2  2022-09-30 14:53:50
# 3  2022-09-30 14:53:50
# 4  2022-09-30 14:53:49

# %%
data4_2['Profile Name'].nunique()
# Out:
# 9

# %%
data4_2.head()
# Out:
#   Profile Name    Esn    Device Type  Acct First Playback Date  \
# 0       User 3  Esn 1  Device Type 4  2022-04-01T09:32:16.028Z
# 1       User 1  Esn 6  Device Type 0  2021-12-24T14:40:29.147Z
# 2       User 2  Esn 6  Device Type 0  2021-12-24T14:40:29.147Z
# 3       User 3  Esn 6  Device Type 0  2021-12-24T14:40:29.147Z
# 4       User 0  Esn 6  Device Type 0  2021-12-24T14:40:29.147Z
#
#     Acct Last Playback Date Acct First Playback Date For User Generated Plays  \
# 0  2022-11-07T12:57:43.624Z                          2022-04-01T09:32:16.028Z
# 1  2022-10-06T17:29:04.497Z                          2021-12-24T14:40:29.147Z
# 2  2022-10-06T17:29:04.497Z                          2021-12-24T14:40:29.147Z
# 3  2022-10-06T17:29:04.497Z                          2021-12-24T14:40:29.147Z
# 4  2022-10-06T17:29:04.497Z                          2021-12-24T14:40:29.147Z
#
#   Acct Last Playback Date For User Generated Plays  \
# 0                         2022-11-07T12:57:43.624Z
# ...

# %%
data4_3.head()
# Out:
#   Profile Name  Game Handle Profile Creation Time Maturity Level Primary Lang  \
# 0       User 0          NaN      29-10-2021 05:42         ADULTS        en-IN
# 1       User 1          NaN      29-10-2021 05:42         ADULTS        en-IN
# 2       User 2          NaN      29-10-2021 05:42         ADULTS        en-IN
# 3       User 3          NaN      29-10-2021 05:42         ADULTS        en-IN
# 4       User 4          NaN      29-10-2021 05:19         ADULTS        en-IN
#
#    Has Auto Playback Max Stream Quality  Profile Lock Enabled  \
# 0                1.0            Unknown                 False
# 1                1.0            Unknown                 False
# 2                1.0            Unknown                 False
# 3                1.0            Unknown                 False
# 4                NaN            Unknown                 False
#
#    Profile Transferred  Profile Transfer Time  \
# 0                False                    NaN
# ...

# %%
data4_4.head()
# Out:
#   Profile Name Country Iso Code    Device  Is Kids Query Typed  \
# 0       User 4               AE  Device 0        0         NaN
# 1       User 4               AE  Device 0        0         NaN
# 2       User 4               AE  Device 0        0         NaN
# 3       User 4               AE  Device 0        0         NaN
# 4       User 4               AE  Device 0        0    the gray
#
#                 Displayed Name  Action           Section        Utc Timestamp
# 0  Manifest: Season 1: "Pilot"    play  prequery_results  2022-08-01 13:59:19
# 1                          NaN  select  prequery_results  2022-08-01 13:59:18
# 2  Manifest: Season 1: "Pilot"    play  prequery_results  2022-08-01 13:59:07
# 3                          NaN  select  prequery_results  2022-08-01 13:59:03
# 4                 The Gray Man     add     title_results  2022-07-17 13:59:23

# %%
data4_5.head()
# Out:
#   Profile Name           Start Time  Duration Attributes  \
# 0       User 1  2022-04-28 16:08:56  00:00:06        NaN
# 1       User 1  2022-04-28 15:54:30  00:09:39        NaN
# 2       User 1  2022-04-28 15:53:20  00:00:06        NaN
# 3       User 1  2022-04-28 15:52:18  00:00:15        NaN
# 4       User 1  2022-04-28 15:49:11  00:01:45        NaN
#
#                                        Title Supplemental Video Type  \
# 0                             Chernobyl 1986                     NaN
# 1  13 Hours: The Secret Soldiers of Benghazi                     NaN
# 2                        Saving Private Ryan                     NaN
# 3                                      Mosul                     NaN
# 4                                  12 Strong                     NaN
#
#      Device Type  Bookmark Latest Bookmark     Country
# 0  Device Type 1  01:02:16        01:02:16  IN (India)
# 1  Device Type 1  02:13:19        02:13:19  IN (India)
# ...

# %% [markdown]
# **data4_1 Cleaning**

# %%
data4_1.isnull().sum()
data4_1.shape
# Out:
# (12104, 6)

# %%
data4_1=data4_1.drop(['Referrer Url','Webpage Url','Navigation Level'], axis=1)

# %%
data4_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12104 entries, 0 to 12103
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Profile Name  12104 non-null  object
#  1   Source        12104 non-null  object
#  2   Click Utc Ts  12104 non-null  object
# dtypes: object(3)
# memory usage: 283.8+ KB

# %%
data4_1['Click Utc Ts']=pd.to_datetime(data4_1['Click Utc Ts'])

# %% [markdown]
# **data4_2 cleaning**

# %%
data4_2.isnull().sum()
# Out:
# Profile Name                                             0
# Esn                                                      0
# Device Type                                              0
# Acct First Playback Date                                17
# Acct Last Playback Date                                 17
# Acct First Playback Date For User Generated Plays       23
# Acct Last Playback Date For User Generated Plays        23
# Profile First Playback Date                             43
# Profile Last Playback Date                              43
# Profile First Playback Date For User Generated Plays    45
# Profile Last Playback Date For User Generated Plays     45
# Deactivation Time                                       83
# dtype: int64

# %%
data4_2.shape
# Out:
# (137, 12)

# %%
data4_2.columns
# Out:
# Index(['Profile Name', 'Esn', 'Device Type', 'Acct First Playback Date',
#        'Acct Last Playback Date',
#        'Acct First Playback Date For User Generated Plays',
#        'Acct Last Playback Date For User Generated Plays',
#        'Profile First Playback Date', 'Profile Last Playback Date',
#        'Profile First Playback Date For User Generated Plays',
#        'Profile Last Playback Date For User Generated Plays',
#        'Deactivation Time'],
#       dtype='object')

# %%
col=['Profile Name','Device Type']
for i in col:
    data4_2=data4_2[col]

# %%
data4_2.isnull().sum()
# Out:
# Profile Name    0
# Device Type     0
# dtype: int64

# %% [markdown]
# **data4_3 cleaning**

# %%
data4_3.columns
# Out:
# Index(['Profile Name', 'Game Handle', 'Profile Creation Time',
#        'Maturity Level', 'Primary Lang', 'Has Auto Playback',
#        'Max Stream Quality', 'Profile Lock Enabled', 'Profile Transferred',
#        'Profile Transfer Time', 'Profile Transferred From Account',
#        'Profile Transferred To Account', 'Date Of Birth', 'Gender', 'Opt-Out',
#        'Privacy And Data Settings'],
#       dtype='object')

# %%
data4_3.isnull().sum()
# Out:
# Profile Name                        0
# Game Handle                         9
# Profile Creation Time               0
# Maturity Level                      0
# Primary Lang                        0
# Has Auto Playback                   2
# Max Stream Quality                  0
# Profile Lock Enabled                0
# Profile Transferred                 0
# Profile Transfer Time               9
# Profile Transferred From Account    9
# Profile Transferred To Account      9
# Date Of Birth                       9
# Gender                              9
# Opt-Out                             4
# Privacy And Data Settings           5
# dtype: int64

# %%
data4_3.shape
# Out:
# (9, 16)

# %%
col=['Profile Name','Profile Creation Time','Maturity Level']
for i in col:
    data4_3=data4_3[col]

# %%
data4_3.head()
# Out:
#   Profile Name Profile Creation Time Maturity Level
# 0       User 0      29-10-2021 05:42         ADULTS
# 1       User 1      29-10-2021 05:42         ADULTS
# 2       User 2      29-10-2021 05:42         ADULTS
# 3       User 3      29-10-2021 05:42         ADULTS
# 4       User 4      29-10-2021 05:19         ADULTS

# %% [markdown]
# **data_4_4 cleaning**

# %%
data4_4.shape
# Out:
# (2616, 9)

# %%
data4_4.isnull().sum()
# Out:
# Profile Name          0
# Country Iso Code      0
# Device                0
# Is Kids               0
# Query Typed         727
# Displayed Name      818
# Action                0
# Section               0
# Utc Timestamp         0
# dtype: int64

# %%
data4_4.columns
# Out:
# Index(['Profile Name', 'Country Iso Code', 'Device', 'Is Kids', 'Query Typed',
#        'Displayed Name', 'Action', 'Section', 'Utc Timestamp'],
#       dtype='object')

# %%
col=['Displayed Name','Section']
data4_4=data4_4.drop(col,axis=1)
data4_4=data4_4.dropna(subset='Query Typed')

# %%
data4_4.shape
# Out:
# (1889, 7)

# %% [markdown]
# **data4_5 cleaning**

# %%
data4_5.shape
# Out:
# (9992, 10)

# %%
data4_5.isnull().sum()
# Out:
# Profile Name                  0
# Start Time                    0
# Duration                      0
# Attributes                 8593
# Title                         0
# Supplemental Video Type    8147
# Device Type                   0
# Bookmark                      0
# Latest Bookmark               0
# Country                       0
# dtype: int64

# %%
col=['Attributes','Supplemental Video Type','Bookmark','Latest Bookmark']
data4_5=data4_5.drop(col,axis=1)

# %%
data4_5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9992 entries, 0 to 9991
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Profile Name  9992 non-null   object
#  1   Start Time    9992 non-null   object
#  2   Duration      9992 non-null   object
#  3   Title         9992 non-null   object
#  4   Device Type   9992 non-null   object
#  5   Country       9992 non-null   object
# dtypes: object(6)
# memory usage: 468.5+ KB

# %%
data4_5.head()
# Out:
#   Profile Name           Start Time  Duration  \
# 0       User 1  2022-04-28 16:08:56  00:00:06
# 1       User 1  2022-04-28 15:54:30  00:09:39
# 2       User 1  2022-04-28 15:53:20  00:00:06
# 3       User 1  2022-04-28 15:52:18  00:00:15
# 4       User 1  2022-04-28 15:49:11  00:01:45
#
#                                        Title    Device Type     Country
# 0                             Chernobyl 1986  Device Type 1  IN (India)
# 1  13 Hours: The Secret Soldiers of Benghazi  Device Type 1  IN (India)
# 2                        Saving Private Ryan  Device Type 1  IN (India)
# 3                                      Mosul  Device Type 1  IN (India)
# 4                                  12 Strong  Device Type 1  IN (India)

# %%
data4_5['Start Time']=pd.to_datetime(data4_5['Start Time'])
data4_5['Duration']=pd.to_datetime(data4_5['Duration'])
# Out:
# C:\Users\dhruv\AppData\Local\Temp\ipykernel_10516\3806902326.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data4_5['Duration']=pd.to_datetime(data4_5['Duration'])

# %% [markdown]
# **merging**

# %% [markdown]
# **merge only 1 and 2 rest all are useless**

# %%
# Merge profile info
data_4 = pd.merge(data4_1, data4_2, on='Profile Name', how='inner')

# %%
data_4
# Out:
#        Profile Name    Source        Click Utc Ts    Device Type
# 0            User 4  Source 0 2022-10-08 14:04:47  Device Type 5
# 1            User 4  Source 0 2022-10-08 14:04:47  Device Type 1
# 2            User 4  Source 0 2022-10-08 14:04:47  Device Type 4
# 3            User 4  Source 0 2022-10-08 14:04:47  Device Type 2
# 4            User 4  Source 0 2022-10-08 14:04:47  Device Type 2
# ...             ...       ...                 ...            ...
# 237945       User 8  Source 0 2023-02-20 03:44:47  Device Type 0
# 237946       User 8  Source 0 2023-02-20 03:44:47  Device Type 1
# 237947       User 8  Source 0 2023-02-20 03:44:47  Device Type 3
# 237948       User 8  Source 0 2023-02-20 03:44:47  Device Type 3
# 237949       User 8  Source 0 2023-02-20 03:44:47  Device Type 8
#
# [237950 rows x 4 columns]

# %%
data_4.isnull().sum()
# Out:
# Profile Name    0
# Source          0
# Click Utc Ts    0
# Device Type     0
# dtype: int64

# %%
data4_3.head()
# Out:
#   Profile Name Profile Creation Time Maturity Level
# 0       User 0      29-10-2021 05:42         ADULTS
# 1       User 1      29-10-2021 05:42         ADULTS
# 2       User 2      29-10-2021 05:42         ADULTS
# 3       User 3      29-10-2021 05:42         ADULTS
# 4       User 4      29-10-2021 05:19         ADULTS

# %%
data4_4.head()
# Out:
#    Profile Name Country Iso Code    Device  Is Kids Query Typed  Action  \
# 4        User 4               AE  Device 0        0    the gray     add
# 5        User 4               AE  Device 0        0    the gray  select
# 11       User 4               AE  Device 0        0        stra    play
# 12       User 4               AE  Device 0        0        stra    play
# 13       User 4               AE  Device 0        0        stra    play
#
#           Utc Timestamp
# 4   2022-07-17 13:59:23
# 5   2022-07-17 13:59:17
# 11  2022-07-01 14:28:04
# 12  2022-07-01 14:13:00
# 13  2022-07-01 14:10:08

# %%
data4_5.head()
# Out:
#   Profile Name          Start Time            Duration  \
# 0       User 1 2022-04-28 16:08:56 2025-06-19 00:00:06
# 1       User 1 2022-04-28 15:54:30 2025-06-19 00:09:39
# 2       User 1 2022-04-28 15:53:20 2025-06-19 00:00:06
# 3       User 1 2022-04-28 15:52:18 2025-06-19 00:00:15
# 4       User 1 2022-04-28 15:49:11 2025-06-19 00:01:45
#
#                                        Title    Device Type     Country
# 0                             Chernobyl 1986  Device Type 1  IN (India)
# 1  13 Hours: The Secret Soldiers of Benghazi  Device Type 1  IN (India)
# 2                        Saving Private Ryan  Device Type 1  IN (India)
# 3                                      Mosul  Device Type 1  IN (India)
# 4                                  12 Strong  Device Type 1  IN (India)

# %%
data_4.to_csv("Netiflix viewing.csv",index=False)
data4_5.to_csv("Netflix_viewing titles.csv",index=False)

# %% [markdown]
# **dataset 5=. Netflix Titles + IMDb Ratings (Merged)**

# %%
data5_credits=pd.read_csv("credits.csv")
data5_titles=pd.read_csv("titles.csv")

# %%
data5_credits.head()
# Out:
#    person_id       id             name                character   role
# 0       3748  tm84618   Robert De Niro            Travis Bickle  ACTOR
# 1      14658  tm84618     Jodie Foster            Iris Steensma  ACTOR
# 2       7064  tm84618    Albert Brooks                      Tom  ACTOR
# 3       3739  tm84618    Harvey Keitel  Matthew 'Sport' Higgins  ACTOR
# 4      48933  tm84618  Cybill Shepherd                    Betsy  ACTOR

# %%
data5_titles.head()
# Out:
#          id                                title   type  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW
# 1   tm84618                          Taxi Driver  MOVIE
# 2  tm154986                          Deliverance  MOVIE
# 3  tm127384      Monty Python and the Holy Grail  MOVIE
# 4  tm120801                      The Dirty Dozen  MOVIE
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  Intent on seeing the Cahulawassee River before...          1972
# 3  King Arthur, accompanied by his squire, recrui...          1975
# 4  12 American military prisoners in World War II...          1967
#
#   age_certification  runtime                                       genres  \
# 0             TV-MA       51                            ['documentation']
# ...

# %%
print(f"Columns of credits:{data5_credits.columns}\n Columns of titles:{data5_titles.columns}")
# Out:
# Columns of credits:Index(['person_id', 'id', 'name', 'character', 'role'], dtype='object')
#  Columns of titles:Index(['id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'genres', 'production_countries',
#        'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity',
#        'tmdb_score'],
#       dtype='object')

# %%
data5_credits=data5_credits.drop(['person_id'], axis=1)
data5_titles=data5_titles.drop(['description','imdb_id','imdb_votes','tmdb_popularity','tmdb_score','seasons'],axis=1)

# %%
data5_credits.shape
# Out:
# (77801, 4)

# %%
data5_titles.shape
# Out:
# (5850, 9)

# %%
data5_credits.isnull().sum()
# Out:
# id              0
# name            0
# character    9772
# role            0
# dtype: int64

# %%
data5_credits=data5_credits.dropna(subset='character')

# %%
data5_titles.isnull().sum()
# Out:
# id                         0
# title                      1
# type                       0
# release_year               0
# age_certification       2619
# runtime                    0
# genres                     0
# production_countries       0
# imdb_score               482
# dtype: int64

# %%
data5_titles=data5_titles.dropna(subset='imdb_score')

# %%
data5_titles['age_certification']=data5_titles['age_certification'].fillna('Not Availavle')

# %%
IMBD = data5_titles.merge(data5_credits, on='id', how='left')

# %%
IMBD.isnull().sum()
# Out:
# id                        0
# title                     0
# type                      0
# release_year              0
# age_certification         0
# runtime                   0
# genres                    0
# production_countries      0
# imdb_score                0
# name                    735
# character               735
# role                    735
# dtype: int64

# %%
IMBD.head()
# Out:
#         id        title   type  release_year age_certification  runtime  \
# 0  tm84618  Taxi Driver  MOVIE          1976                 R      114
# 1  tm84618  Taxi Driver  MOVIE          1976                 R      114
# 2  tm84618  Taxi Driver  MOVIE          1976                 R      114
# 3  tm84618  Taxi Driver  MOVIE          1976                 R      114
# 4  tm84618  Taxi Driver  MOVIE          1976                 R      114
#
#                genres production_countries  imdb_score
# 0  ['drama', 'crime']               ['US']         8.2
# 1  ['drama', 'crime']               ['US']         8.2
# 2  ['drama', 'crime']               ['US']         8.2
# 3  ['drama', 'crime']               ['US']         8.2
# 4  ['drama', 'crime']               ['US']         8.2

# %%
IMBD=IMBD.drop(['role','name','character'],axis=1)

# %%
final=IMBD.drop_duplicates()
final.shape
# Out:
# (5368, 9)

# %%
final.to_csv("Netflix IMBD.csv", index=False)
