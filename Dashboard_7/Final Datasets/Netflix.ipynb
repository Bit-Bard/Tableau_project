# %%
import pandas as pd
import numpy as np

# %%
data1=pd.read_csv("Netflix IMBD.csv")
print(f"Columns of Netflix IMBD :{data1.columns}")
# Out:
# Columns of Netflix IMBD :Index(['id', 'title', 'type', 'release_year', 'age_certification', 'runtime',
#        'genres', 'production_countries', 'imdb_score'],
#       dtype='object')

# %%
data1.head()
# Out:
#          id                            title   type  release_year  \
# 0   tm84618                      Taxi Driver  MOVIE          1976
# 1  tm154986                      Deliverance  MOVIE          1972
# 2  tm127384  Monty Python and the Holy Grail  MOVIE          1975
# 3  tm120801                  The Dirty Dozen  MOVIE          1967
# 4   ts22164     Monty Python's Flying Circus   SHOW          1969
#
#   age_certification  runtime                                       genres  \
# 0                 R      114                           ['drama', 'crime']
# 1                 R      109  ['drama', 'action', 'thriller', 'european']
# 2                PG       91              ['fantasy', 'action', 'comedy']
# 3     Not Availavle      150                            ['war', 'action']
# 4             TV-14       30                       ['comedy', 'european']
#
#   production_countries  imdb_score
# 0               ['US']         8.2
# 1               ['US']         7.7
# ...

# %%
data2=pd.read_csv("Netflix Movies and TV Shows[Cleaned].csv")
print(f"Columns of Netflix Movies and tv shows:{data2.columns}")
# Out:
# Columns of Netflix Movies and tv shows:Index(['show_id', 'type', 'title', 'director', 'cast', 'country',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
data3=pd.read_csv("Netflix Plans and Prices[Cleaned].csv")
print(f"Columns of Netflix Plans and prices:{data3.columns}")
# Out:
# Columns of Netflix Plans and prices:Index(['Country', 'Code', 'Mobile_USD', 'Basic_USD', 'Standard_USD',
#        'Premium_USD'],
#       dtype='object')

# %%
data4=pd.read_csv("Netflix Sub and Revnue overtime [Cleaned].csv")
print(f"Columns of Netflix sub and revenue overtime:{data4.columns}")
# Out:
# Columns of Netflix sub and revenue overtime:Index(['Date', 'Global Revenue', 'Revenue_US_Canada',
#        'Revenue_Europe_MiddleEast_Africa', 'Revenue_LatinAmerica',
#        'Revenue_AsiaPacific', 'Subscribers_US_Canada',
#        'Subscribers_Europe_MiddleEast_Africa', 'Subscribers_LatinAmerica',
#        'Subscribers_AsiaPacific', 'ARPU_US_Canada',
#        'ARPU_Europe_MiddleEast_Africa', 'ARPU_LatinAmerica',
#        'ARPU_AsiaPacific', 'Netflix Streaming Memberships '],
#       dtype='object')

# %%
data5=pd.read_csv("Netflix_viewing titles.csv")
print(f"Columns of Netflix viewing titles:{data5.columns}")
# Out:
# Columns of Netflix viewing titles:Index(['Profile Name', 'Start Time', 'Duration', 'Title', 'Device Type',
#        'Country'],
#       dtype='object')

# %%
data6=pd.read_csv("Netiflix viewing.csv")
print(f"Columns of Netflix viewing:{data6.columns}")
# Out:
# Columns of Netflix viewing:Index(['Profile Name', 'Source', 'Click Utc Ts', 'Device Type'], dtype='object')
