# %%
import numpy as np
import pandas as pd

# %%
a1=pd.read_csv("Apple_Fin.csv")
a1.columns
# Out:
# Index(['Variable', '2012-12-31', '2013-12-31', '2014-12-31', '2015-12-31',
#        '2016-12-31', '2017-12-31', '2018-12-31', '2019-12-31', '2020-12-31',
#        '2021-12-31'],
#       dtype='object')

# %%
a2=pd.read_csv("apple_segment_revenue.csv")
a2.columns
# Out:
# Index(['Year', 'Date', 'Quarter', 'NetSales_Products', 'NetSales_Services',
#        'NetSales_Total', 'COG_Products', 'COG_Services', 'COG_Total',
#        'Gross_margin', 'OperatingExpase_RND', 'OperatingExpase_SGA',
#        'OperatingExpase_Total', 'Operating_income', 'Other_income_expanse',
#        'Income_before_provision_for_income_taxes',
#        'Provision_for_income_taxes', 'Net_income', 'Earnings_per_share_Basic',
#        'Earnings_per_share_Diluted', 'AssetsCurrent_Cash',
#        'AssetsCurrent_Marketable_securities',
#        'AssetsCurrent_Accounts_receivable', 'AssetsCurrent_Inventories',
#        'AssetsCurrent_non_trade_receivables', 'AssetsCurrent_Other',
#        'AssetsCurrent_Total', 'AssetsNC_Marketable_securities', 'AssetsNC_PPE',
#        'AssetsNC_Other', 'AssetsNC_Total', 'Assets_Total',
#        'LiabilitiesCurrent_Accounts payable', 'LiabilitiesCurrent_Other',
#        'LiabilitiesCurrent_Deferred_revenue',
# ...

# %%
t1=pd.read_csv("Tesla_Financial_format.csv")
t1.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Open', 'High', 'Low', 'Close*', 'Adj Close**',
#        'Volume'],
#       dtype='object')

# %%
t2=pd.read_csv("Tesla_stock.csv")
t2.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')
