# %%
import pandas as pd
import numpy as np

# %%
T1=pd.read_csv("C:\\Users\\dhruv\\OneDrive\\Documents\\Desktop\\Dashboards_prac\\Dashboard_6\\Apple\\Apple_Financial\\apple_income_statement.csv")
T1.head()
# Out:
#                          Unnamed: 0  2012-12-31  2013-12-31  2014-12-31  \
# 0                              Cash           0           0           0
# 1                Cash & Equivalents        5490        6081        7341
# 2            Short Term Investments          29          14           0
# 3   Cash and Short Term Investments        5519        6095        7341
# 4  Accounts Receivable - Trade, Net        8831        8326        7699
#
#    2015-12-31  2016-12-31  2017-12-31  2018-12-31  2019-12-31  2020-12-31  \
# 0           0           0           0           0           0           0
# 1        6460        7168        8261        7857        8284        9352
# 2           0           0           0           1           0           0
# 3        6460        7168        8261        7858        8284        9352
# 4        6677        5919        7376        8767        8484        7317
#
#    2021-12-31
# 0           0
# 1        9254
# 2           0
# 3        9254
# ...

# %%
T1.shape
# Out:
# (31, 11)

# %%
T1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  31 non-null     object
#  1   2012-12-31  31 non-null     int64
#  2   2013-12-31  31 non-null     int64
#  3   2014-12-31  31 non-null     int64
#  4   2015-12-31  31 non-null     int64
#  5   2016-12-31  31 non-null     int64
#  6   2017-12-31  31 non-null     int64
#  7   2018-12-31  31 non-null     int64
#  8   2019-12-31  31 non-null     int64
#  9   2020-12-31  31 non-null     int64
#  10  2021-12-31  31 non-null     int64
# dtypes: int64(10), object(1)
# memory usage: 2.8+ KB

# %%
T1['Unnamed: 0'].unique()
# Out:
# array(['Cash', 'Cash & Equivalents', 'Short Term Investments',
#        'Cash and Short Term Investments',
#        'Accounts Receivable - Trade, Net', 'Total Receivables, Net',
#        'Total Inventory', 'Other Current Assets, Total',
#        'Total Current Assets', 'Property/Plant/Equipment, Total - Gross',
#        'Accumulated Depreciation, Total',
#        'Property/Plant/Equipment, Total - Net', 'Long Term Investments',
#        'Other Long Term Assets, Total', 'Total Assets',
#        'Accounts Payable', 'Notes Payable/Short Term Debt',
#        'Current Port. of  LT Debt/Capital Leases',
#        'Other Current liabilities, Total', 'Total Current Liabilities',
#        'Long Term Debt', 'Total Long Term Debt', 'Total Debt',
#        'Other Liabilities, Total', 'Total Liabilities',
#        'Common Stock, Total', 'Retained Earnings (Accumulated Deficit)',
#        'Unrealized Gain (Loss)', 'Other Equity, Total', 'Total Equity',
# ...

# %%
T1.rename(columns={'Unnamed: 0': 'Variable'}, inplace=True)

# %%
T1.to_csv("Apple_Fin.csv", index=False)

# %% [markdown]
# ### Quartely

# %%
Q1=pd.read_csv("C:\\Users\\dhruv\\OneDrive\\Documents\\Desktop\\Dashboards_prac\\Dashboard_6\\Apple\\Apple_Quartely\\Apple_DB.csv")
Q1.head()
# Out:
#    Year        Date  Quarter  NetSales_Products  NetSales_Services  \
# 0  2023  09/01/2023        4              67184              22314
# 1  2023  06/01/2023        3              60584              21213
# 2  2023  04/01/2023        2              73929              20907
# 3  2022  12/01/2022        1              96388              20766
# 4  2022  09/01/2022        4              70958              19188
#
#    NetSales_Total  COG_Products  COG_Services  COG_Total  Gross_margin  ...  \
# 0           89498         42586          6485      49071         40427  ...
# 1           81797         39136          6248      45384         36413  ...
# 2           94836         46795          6065      52860         41976  ...
# 3          117154         60765          6057      66822         50332  ...
# 4           90146         46387          5664      52051         38095  ...
#
#    LiabilitiesNC_Term_debt  LiabilitiesNC_Other  LiabilitiesNC_Total  \
# ...

# %%
Q2=pd.read_csv("C:\\Users\\dhruv\\OneDrive\\Documents\\Desktop\\Dashboards_prac\\Dashboard_6\\Apple\\Apple_Quartely\\Data for Training - Apple DB - Accumulated Statement.csv")
Q2.head()
# Out:
#                 Year    2023  2023.1   2023.2     2022  2022.1  2022.2  \
# 0               Date  9.2023  6.2023  04.2023  12.2023  9.2022  6.2022
# 1            Quarter      Q4      Q3       Q2       Q1      Q4      Q3
# 2  NetSales_Products  67,184  60,584   73,929   96,388  70,958  63,355
# 3  NetSales_Services  22,314  21,213   20,907   20,766  19,188  19,604
# 4     NetSales_Total  89,498  81,797   94,836  117,154  90,146  82,959
#
#    2022.3     2021  2021.1  ...  2021.3     2020   2020.1   2020.2   2020.3  \
# 0  3.2022  12.2021  9.2021  ...  3.2021  12.2020  09.2020  06.2020  03.2020
# 1      Q2       Q1      Q4  ...      Q2       Q1       Q4       Q3       Q2
# 2  77,457  104,429  65,083  ...  72,683   95,678   50,149   46,529   44,965
# 3  19,821   19,516  18,277  ...  16,901   15,761   14,549   13,156   13,348
# 4  97,278  123,945  83,360  ...  89,584  111,439   64,698   59,685   58,313
#
#       2019   2019.1   2019.2   2019.3     2018
# ...

# %%
Q1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 48 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Year                                          20 non-null     int64
#  1   Date                                          20 non-null     object
#  2   Quarter                                       20 non-null     int64
#  3   NetSales_Products                             20 non-null     int64
#  4   NetSales_Services                             20 non-null     int64
#  5   NetSales_Total                                20 non-null     int64
#  6   COG_Products                                  20 non-null     int64
#  7   COG_Services                                  20 non-null     int64
#  8   COG_Total                                     20 non-null     int64
# ...

# %%
Q1['Date']=pd.to_datetime(Q1['Date'], format='%d/%m/%Y')

# %%
Q1.to_csv("apple_segment_revenue.csv",index=False)
